# %% [markdown]
# <a href="https://colab.research.google.com/github/ezzatmostafa96/Independent-Projects/blob/master/ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.

# %%
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1715ac77-c02c-456e-9716-f60c2277e4ae" name="files[]" multiple disabled />
#      <output id="result-1715ac77-c02c-456e-9716-f60c2277e4ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2.jpg

# %%
extractedInformation = pytesseract.image_to_string(Image.open('2.jpg'))

# %%
print(extractedInformation)
# Out:
# 1.1 Whatis computer vision?
#
# As humans, we perceive the three-dimensional Structure of the world around us with apparent
# case. Think of how vivid the three-dimensional percept is when you look at a vase of flowers
# sitting on the table next to you. You can tell the shape and translucency of each petal through
# the subtle patterns of light and shading that play across its surface and effortlessly segment
# each flower from the background of the scene (Figure 1.1). Looking at a framed group por-
# trait, you can easily count (and name) all of the people in the picture and even guess at their
# emotions from their facial appearance. Perceptual psychologists have spent decades trying to
# understand how the visual system works and, even though they can devise optical illusions!
# to tease apart some of its principles (Figure 1.3), a complete solution to this puzzle remains
# elusive (Marr 1982; Palmer 1999; Livingstone 2008).

# %%
# !pip install googletrans
# Out:
# ...
#   Created wheel for googletrans: filename=googletrans-2.4.0-cp36-none-any.whl size=15777 sha256=956aca859f5192dc755b98fc1e3cb6f0dfdcda62920f9988d211b1bbcfb51d27
#   Stored in directory: /root/.cache/pip/wheels/50/d6/e7/a8efd5f2427d5eb258070048718fa56ee5ac57fd6f53505f95
# Successfully built googletrans
# ...

# %%
# Importing the necessary libraries
import pandas as pd
import googletrans
from googletrans import Translator

# %%
translator = Translator()

# %%
translations = {}

# %%
translations = translator.translate(extractedInformation)

# %%
translations

# %%
# !git clone https://github.com/zeyadetman/Targmly.git
# %cd Targmly
# !pip install -r requirements
# !python targmly.py
# Out:
# Cloning into 'Targmly'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39
# Unpacking objects: 100% (39/39), done.
# /content/Targmly
# ...
#      |████████████████████████████████| 153kB 2.5MB/s
# ...
#      |████████████████████████████████| 61kB 2.9MB/s
# ...
#      |████████████████████████████████| 61kB 2.9MB/s
# ...
#      |████████████████████████████████| 92kB 3.7MB/s
# ...
#      |████████████████████████████████| 133kB 5.1MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-2.2.0-cp36-none-any.whl size=14679 sha256=a111729da3c094569fa057595b6b65459196a16e78340f87c5b2247227219e05
#   Stored in directory: /root/.cache/pip/wheels/03/67/83/38f65b30bb5ca9296e5045c50a3f4876eec8df0c47adaca385
# ...
#   Created wheel for plyer: filename=plyer-1.3.0-cp36-none-any.whl size=83028 sha256=b64890e8b5ea2df5e0abe1220524c2a2282d65e0a8e8463cdfff8ad3e6672b01
# ...

# %%
translatedWord = Translator().translate(word, dest='ar')

# %%
word = "love"

# %%
import googletrans

print(googletrans.LANGUAGES)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'latin', 'lv': 'la
# ...

# %%
result = translator.translate('Mitä sinä teet')

# %%
result.text
# Out:
# 'What are you doing'

# %%
print(translatedWord.text)
# Out:
# 1.1 هاتيس رؤية الكمبيوتر؟
#
# كبشر، ونحن ننظر الى هيكل ثلاثي الأبعاد في العالم من حولنا مع واضحة
# قضية. التفكير في كيفية حية في الإدراك ثلاثي الأبعاد هو عندما تنظر في إناء من الزهور
# جالسا على الطاولة إلى جانبك. يمكنك معرفة شكل والشفافية في كل بتلة من خلال
# أنماط خفية من الضوء والتظليل أن اللعب عبر سطحه وقطاع جهد
# كل زهرة من خلفية المشهد (الشكل 1.1). وعند النظر إلى مجموعة مؤطرة por-
# سمة، يمكنك الاعتماد بسهولة (واسم) كل الناس في الصورة وحتى تخمين في اجتماعهم
# العواطف من مظهرهم الوجه. وقد قضى علماء النفس الإدراكي عقود في محاولة ل
# فهم الكيفية التي يعمل بها النظام البصري، وعلى الرغم من أنها يمكن وضع خداع بصري!
# لندف بعيدا بعض من مبادئه (الشكل 1.3)، حلا كاملا لبقايا لغز هذا
# بعيد المنال (مار 1982؛ بالمر 1999؛ ليفينغستون 2008).

# %%
extractedInformation
# Out:
# '1.1 Whatis computer vision?\n\nAs humans, we perceive the three-dimensional Structure of the world around us with apparent\ncase. Think of how vivid the three-dimensional percept is when you look at a vase of flowers\nsitting on the table next to you. You can tell the shape and translucency of each petal through\nthe subtle patterns of light and shading that play across its surface and effortlessly segment\neach flower from the background of the scene (Figure 1.1). Looking at a framed group por-\ntrait, you can easily count (and name) all of the people in the picture and even guess at their\nemotions from their facial appearance. Perceptual psychologists have spent decades trying to\nunderstand how the visual system works and, even though they can devise optical illusions!\nto tease apart some of its principles (Figure 1.3), a complete solution to this puzzle remains\nelusive (Marr 1982; Palmer 1999; Livingstone 2008).'

# %%
word = extractedInformation

# %%
# !pip install gTTS
# Out:
# ...
#   Created wheel for gtts-token: filename=gTTS_token-1.1.3-cp36-none-any.whl size=4097 sha256=61ca03e13e1b9904a30f9f2be6fe31d37952604df984f089d5d9a0af5c216ef2
#   Stored in directory: /root/.cache/pip/wheels/dd/11/61/33f7e51bf545e910552b2255eead2a7cd8ef54064b46dceb34
# Successfully built gtts-token
# ...

# %%
from gtts import gTTS

# %%
import os

# %%
mytext = translatedWord.text

# %%
language = 'ar'

# %%
myobj = gTTS(text=mytext, lang=language, slow=False)

# %%
myobj.save("welcome_new.mp3")

# %%
response = requests.get("https://img.srgcdn.com/e//MkhIN3VMem9GajZybDVPSzNWUUouanBn.jpg")
image_bytes = io.BytesIO(response.content)

img = PIL.Image.open(image_bytes)
img.show()

# %%
pip install requests

# %%
import requests
from io import StringIO
import io
from PIL import *
import PIL

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=753x394 at 0x7F78E11816A0>

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/unnamed.jpg'))

# %%
print(extractedInformation)
# Out:
# THE BIG SLEEP
# by Raymond Chandler
#
# It was about eleven o'clock in the morning, mid October, with the sun not
# shining and a look of hard wet rain in the clearness of the foothills. I was
# wearing my powder-blue suit, with dark blue shirt, tie and display
# handkerchief, black brogues, black wool socks with dark blue clocks on
# them, I was neat, clean, shaved and sober, and I didn't care who knew tt. 1
# was everything the well-dressed private detective ought to be. I was
# calling on four million dollars.
#
# ‘The main hallway of the Sternwood place was two stories high. Over the
# entrance doors, which would have let in a troop of Indian elephants, there
# was a broad stained-glass panel showing a knight in dark armor rescuing

# %%
word = extractedInformation
translatedWord = Translator().translate(extractedInformation, dest='ar')

# %%
print(translatedWord.text)
# Out:
# THE BIG SLEEP
# بواسطة ريمون شاندلر
#
# وكان نحو 11:00 في الصباح، منتصف أكتوبر، والشمس لا
# مشرقة ونظرة من المطر الرطب الصلب في وضوح سفوح. انا كنت
# ارتداء بلدي دعوى مسحوق أزرق، مع الأزرق الداكن قميص وربطة عنق وعرض
# منديل، تصليحه السوداء والجوارب الصوف الأسود مع الساعات زرقاء داكنة على
# لهم، وكان أنيق، نظيفة، حلق والرصين، وأنا لا يهمني من يعرف ترينيداد وتوباغو. 1
# كان كل شيء يجب أن يكون المخبر الخاص هندامه. انا كنت
# داعيا أربعة ملايين دولار.
#
# "وكان المدخل الرئيسي للمكان Sternwood قصتين عالية. على مدار
# أبواب المدخل، التي من شأنها أن تسمح بدخول قوات من الفيلة الهندية، هناك
# ولوحة واسعة من الزجاج الملون تظهر فارس في الظلام درع الإنقاذ

# %%
img = PIL.Image.open("/content/unnamed.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x228 at 0x7F78DFF7D3C8>

# %%
from gtts import gTTS 
import os 
mytext = translatedWord.text
language = 'ar'
myobj = gTTS(text=mytext, lang=language, slow=False) 
myobj.save("welcome_new1.mp3")

# %%
# Needed imports
import numpy as np
from IPython.display import Audio
from scipy.io import wavfile
# Generate a player for mono sound
Audio("/content/Targmly/welcome_new1.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
